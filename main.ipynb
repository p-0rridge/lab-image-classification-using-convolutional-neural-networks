# %% [markdown]
# # Lab : Image Classification using Convolutional Neural Networks
#
# At the end of this laboratory, you would get familiarized with
#
# *   Creating deep networks using Keras
# *   Steps necessary in training a neural network
# *   Prediction and performance analysis using neural networks
#
# ---

# %% [markdown]
# # **In case you use a colaboratory environment**
# By default, Colab notebooks run on CPU.
# You can switch your notebook to run with GPU.
#
# In order to obtain access to the GPU, you need to choose the tab Runtime and then select “Change runtime type” as shown in the following figure:
#
# ![Changing runtime](https://miro.medium.com/max/747/1*euE7nGZ0uJQcgvkpgvkoQg.png)
#
# When a pop-up window appears select GPU. Ensure “Hardware accelerator” is set to GPU.

# %% [markdown]
# # **Working with a new dataset: CIFAR-10**
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images. More information about CIFAR-10 can be found [here](https://www.cs.toronto.edu/~kriz/cifar.html).
#
# In Keras, the CIFAR-10 dataset is also preloaded in the form of four Numpy arrays. x_train and y_train contain the training set, while x_test and y_test contain the test data. The images are encoded as Numpy arrays and their corresponding labels ranging from 0 to 9.
#
# Your task is to:
#
# *   Visualize the images in CIFAR-10 dataset. Create a 10 x 10 plot showing 10 random samples from each class.
# *   Convert the labels to one-hot encoded form.
# *   Normalize the images.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 1512s 9us/step

# %%
#Visualize the images in CIFAR-10 dataset. Create a 10 x 10 plot showing 10 random samples from each class.
import numpy as np
import matplotlib.pyplot as plt

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10, 10))

for class_idx in range(10):
    class_indices = np.where(y_train == class_idx)[0]

    for i in range(10):
        plt.subplot(10, 10, class_idx * 10 + i + 1)

        plt.imshow(x_train[class_indices[i]])
        plt.axis('off')

        if i == 0:
            plt.text(-5, 16, class_names[class_idx], ha='right', va='center', weight='bold')

plt.tight_layout()
plt.show()

# %%
#Convert the labels to one-hot encoded form.

from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

print(y_train.shape)
print(y_test.shape)
# Out:
# (50000, 10)
# (10000, 10)

# %%
#Normalize the images.

x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

print(x_train.shape)
print(x_test.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %% [markdown]
# ## Define the following model (same as the one in tutorial)
#
# For the convolutional front-end, start with a single convolutional layer with a small filter size (3,3) and a modest number of filters (32) followed by a max pooling layer.
#
# Use the input as (32,32,3).
#
# The filter maps can then be flattened to provide features to the classifier.
#
# Use a dense layer with 100 units before the classification layer (which is also a dense layer with softmax activation).

# %%
from keras.backend import clear_session
clear_session()

# %%
from tensorflow.keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(100, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 7200)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 100)            │       720,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 722,006 (2.75 MB)
#  Trainable params: 722,006 (2.75 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# *   Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric.
# *   Use the above defined model to train CIFAR-10 and train the model for 50 epochs with a batch size of 512.

# %%
from keras.optimizers import SGD
opt = SGD(learning_rate = 0.01, momentum=0.0)

model.compile(loss='categorical_crossentropy',
              optimizer = opt,
              metrics=['accuracy'])

# %%
# final check before training

# 1. Prüfen, ob die Daten da sind und die richtige Form haben
print("--- DATEN-CHECK ---")
print("Bilder Trainingsset (Sollte 50000, 32, 32, 3 sein):", x_train.shape)
print("Labels Trainingsset (Sollte 50000, 10 sein):", y_train.shape)

# 2. Prüfen, ob die Normalisierung geklappt hat (Werte müssen zwischen 0 und 1 sein)
print("\n--- NORMALISIERUNGS-CHECK ---")
print("Maximaler Pixelwert (Sollte 1.0 sein):", x_train.max())
print("Minimaler Pixelwert (Sollte 0.0 sein):", x_train.min())

# 3. Prüfen, ob das Modell bereit ist
print("\n--- MODELL-CHECK ---")
try:
    print("Modell-Eingangsform:", model.input_shape)
    print("Modell-Ausgangsform (Sollte (None, 10) sein):", model.output_shape)
    print("\n=> ALLES PERFEKT! Du kannst das Training sicher starten.")
except NameError:
    print("\n=> FEHLER: Das Modell wurde noch nicht definiert! Bitte die Modell-Zelle noch mal ausführen.")
# Out:
# --- DATEN-CHECK ---
# Bilder Trainingsset (Sollte 50000, 32, 32, 3 sein): (50000, 32, 32, 3)
# Labels Trainingsset (Sollte 50000, 10 sein): (50000, 10)
#
# --- NORMALISIERUNGS-CHECK ---
# Maximaler Pixelwert (Sollte 1.0 sein): 1.0
# Minimaler Pixelwert (Sollte 0.0 sein): 0.0
#
# --- MODELL-CHECK ---
# Modell-Eingangsform: (None, 32, 32, 3)
# Modell-Ausgangsform (Sollte (None, 10) sein): (None, 10)
#
# => ALLES PERFEKT! Du kannst das Training sicher starten.

# %%
history = model.fit(x_train, y_train, batch_size=1024, epochs=25, validation_data=(x_test, y_test))
# Out:
# Epoch 1/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.2146 - loss: 2.1735 - val_accuracy: 0.2654 - val_loss: 2.0893
# Epoch 2/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.2795 - loss: 2.0430 - val_accuracy: 0.2671 - val_loss: 2.0263
# Epoch 3/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.3022 - loss: 1.9724 - val_accuracy: 0.3215 - val_loss: 1.9342
# Epoch 4/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3269 - loss: 1.9126 - val_accuracy: 0.3116 - val_loss: 1.9011
# Epoch 5/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.3468 - loss: 1.8641 - val_accuracy: 0.3555 - val_loss: 1.8466
# Epoch 6/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.3620 - loss: 1.8294 - val_accuracy: 0.3650 - val_loss: 1.8270
# Epoch 7/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.3711 - loss: 1.8011 - val_accuracy: 0.3794 - val_loss: 1.7741
# Epoch 8/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.3850 - loss: 1.7648 - val_accuracy: 0.3813 - val_loss: 1.7514
# Epoch 9/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.3954 - loss: 1.7351 - val_accuracy: 0.4046 - val_loss: 1.7148
# Epoch 10/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4093 - loss: 1.7074 - val_accuracy: 0.4109 - val_loss: 1.6968
# Epoch 11/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4136 - loss: 1.6885 - val_accuracy: 0.3877 - val_loss: 1.7146
# Epoch 12/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4183 - loss: 1.6674 - val_accuracy: 0.4271 - val_loss: 1.6489
# Epoch 13/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4318 - loss: 1.6374 - val_accuracy: 0.4264 - val_loss: 1.6408
# Epoch 14/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4377 - loss: 1.6191 - val_accuracy: 0.4413 - val_loss: 1.6095
# Epoch 15/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.4421 - loss: 1.6066 - val_accuracy: 0.4495 - val_loss: 1.5875
# Epoch 16/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4503 - loss: 1.5855 - val_accuracy: 0.4554 - val_loss: 1.5787
# Epoch 17/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4545 - loss: 1.5683 - val_accuracy: 0.4591 - val_loss: 1.5576
# Epoch 18/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4619 - loss: 1.5480 - val_accuracy: 0.4540 - val_loss: 1.5521
# Epoch 19/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4695 - loss: 1.5313 - val_accuracy: 0.4732 - val_loss: 1.5258
# Epoch 20/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4758 - loss: 1.5170 - val_accuracy: 0.4771 - val_loss: 1.5153
# Epoch 21/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4774 - loss: 1.5049 - val_accuracy: 0.4687 - val_loss: 1.5162
# Epoch 22/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4811 - loss: 1.4944 - val_accuracy: 0.4795 - val_loss: 1.4890
# Epoch 23/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4836 - loss: 1.4876 - val_accuracy: 0.4908 - val_loss: 1.4697
# Epoch 24/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4848 - loss: 1.4732 - val_accuracy: 0.4909 - val_loss: 1.4628
# Epoch 25/25
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4933 - loss: 1.4562 - val_accuracy: 0.4841 - val_loss: 1.4674

# %% [markdown]
# *   Plot the cross entropy loss curve and the accuracy curve

# %%
plt.subplot(211)
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')

plt.subplot(212)
plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='green', label='train')
plt.show()

# %% [markdown]
# ## Defining Deeper Architectures: VGG Models
#
# *   Define a deeper model architecture for CIFAR-10 dataset and train the new model for 50 epochs with a batch size of 512. We will use VGG model as the architecture.
#
# Stack two convolutional layers with 32 filters, each of 3 x 3.
#
# Use a max pooling layer and next flatten the output of the previous layer and add a dense layer with 128 units before the classification layer.
#
# For all the layers, use ReLU activation function.
#
# Use same padding for the layers to ensure that the height and width of each layer output matches the input

# %%
from keras.backend import clear_session
clear_session()

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform', input_shape=(32, 32, 3)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# *   Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric.
# *   Use the above defined model to train CIFAR-10 and train the model for 50 epochs with a batch size of 512.

# %%
n_epoch = 50
batch_size = 512

from keras.optimizers import SGD
opt = SGD(learning_rate = 0.01, momentum=0.0)

model.compile(loss='categorical_crossentropy',
              optimizer = opt,
              metrics=['accuracy'])

# %%
deep_history = history = model.fit(x_train, y_train, batch_size=batch_size, epochs=n_epoch, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - accuracy: 0.2276 - loss: 2.1374 - val_accuracy: 0.2475 - val_loss: 2.1583
# Epoch 2/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.3093 - loss: 1.9578 - val_accuracy: 0.3198 - val_loss: 1.9365
# Epoch 3/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.3536 - loss: 1.8419 - val_accuracy: 0.3409 - val_loss: 1.8489
# Epoch 4/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.3805 - loss: 1.7707 - val_accuracy: 0.4028 - val_loss: 1.7161
# Epoch 5/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0
50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6377 - loss: 1.0485 - val_accuracy: 0.5978 - val_loss: 1.1492
# Epoch 39/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.6401 - loss: 1.0379 - val_accuracy: 0.5966 - val_loss: 1.1641
# Epoch 40/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6462 - loss: 1.0238 - val_accuracy: 0.5888 - val_loss: 1.1621
# Epoch 41/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6481 - loss: 1.0142 - val_accuracy: 0.5774 - val_loss: 1.2032
# Epoch 42/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6521 - loss: 1.0019 - val_accuracy: 0.6050 - val_loss: 1.1285
# Epoch 43/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6576 - loss: 0.9925 - val_accuracy: 0.6065 - val_loss: 1.1225
# Epoch 44/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6588 - loss: 0.9884 - val_accuracy: 0.6154 - val_loss: 1.0889
# Epoch 45/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.6647 - loss: 0.9707 - val_accuracy: 0.6187 - val_loss: 1.0937
# Epoch 46/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6671 - loss: 0.9647 - val_accuracy: 0.6101 - val_loss: 1.1069
# Epoch 47/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6720 - loss: 0.9496 - val_accuracy: 0.6245 - val_loss: 1.0725
# Epoch 48/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6739 - loss: 0.9445 - val_accuracy: 0.6128 - val_loss: 1.1166
# Epoch 49/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6752 - loss: 0.9424 - val_accuracy: 0.6204 - val_loss: 1.0785
# Epoch 50/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6787 - loss: 0.9291 - val_accuracy: 0.5983 - val_loss: 1.1398

# %%
model.save('deep_cifar_model.keras')

# %% [markdown]
# *   Compare the performance of both the models by plotting the loss and accuracy curves of both the training steps. Does the deeper model perform better? Comment on the observation.

# %%
# Your code here :

# %% [markdown]
# **Comment on the observation**
#
# *(Double-click or enter to edit)*
#
# ...

# %% [markdown]
# *   Use predict function to predict the output for the test split
# *   Plot the confusion matrix for the new model and comment on the class confusions.

# %%
import tensorflow as tf
from tensorflow import keras

loaded_model = keras.models.load_model('deep_cifar_model.keras')

# %% [markdown]
# **Comment here :**
#
# *(Double-click or enter to edit)*
#
# ...

# %% [markdown]
# *    Print the test accuracy for the trained model.

# %%
# Your code here :

# %% [markdown]
# ## Define the complete VGG architecture.
#
# Stack two convolutional layers with 64 filters, each of 3 x 3 followed by max pooling layer.
#
# Stack two more convolutional layers with 128 filters, each of 3 x 3, followed by max pooling, followed by two more convolutional layers with 256 filters, each of 3 x 3, followed by max pooling.
#
# Flatten the output of the previous layer and add a dense layer with 128 units before the classification layer.
#
# For all the layers, use ReLU activation function.
#
# Use same padding for the layers to ensure that the height and width of each layer output matches the input
#
# *   Change the size of input to 64 x 64.

# %%
from keras.backend import clear_session
clear_session()

# %%
# Your code here :

# %% [markdown]
# *   Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric.
# *   Use the above defined model to train CIFAR-10 and train the model for 10 epochs with a batch size of 512.
# *   Predict the output for the test split and plot the confusion matrix for the new model and comment on the class confusions.

# %%
# Your code here :

# %% [markdown]
# # Understanding deep networks
#
# *   What is the use of activation functions in network? Why is it needed?
# *   We have used softmax activation function in the exercise. There are other activation functions available too. What is the difference between sigmoid activation and softmax activation?
# *   What is the difference between categorical crossentropy and binary crossentropy loss?

# %% [markdown]
# **Write the answers below :**
#
# 1 - Use of activation functions:
#
#
#
# _
#
# 2 - Key Differences between sigmoid and softmax:
#
#
#
# _
#
# 3 - Key Differences between categorical crossentropy and binary crossentropy loss:
#
#
# _
